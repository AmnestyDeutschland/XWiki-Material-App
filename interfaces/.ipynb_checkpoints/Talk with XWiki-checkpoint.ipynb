# %% [markdown]
# # XWiki Talker
# ## Anforderungen
# ### Grundlegend
# * [X] Mit REST-Api verbinden
# * [X] Seite aufrufen & anzeigen
# * [X] Objekt aufrufen & anzeigen
# * [ ] Interface zur Nutzung durch andere
#
# ### Kontakte anlegen und updaten
# * [ ] Seite anlegen
# * [ ] Objekt von csv lesen
# * [ ] Objekt hinzufügen
# * [ ] Objekt aufrufen und Infos abgleichen
#
# ### Dokumente anlegen bei Migration
# * [ ] Anhang hinzufügen
#
# ### Automatische Seitenmigration
# * [ ] Formattierung anpassen

# %%
import requests
from requests.auth import HTTPBasicAuth

class WikiTalker:
    """Class to connect to a password-protected xwiki page using the api."""
    def __init__(self, username="", password="", baseurl = "https://amnesty.cloud.xwiki.com"):
        self.baseurl = baseurl
        self.auth = None
        if username and password:
            self.create_handler(username, password)
        self.querystore = {}
        
    def create_handler(self, username, password):
        self.auth = HTTPBasicAuth(username, password)

    def get_response(self, fullstring = "", querystring="", asjson = True):
        """Sends query-string to wikipage, returns result as dictionary from json format."""
        query = ""
        if fullstring:
            query = fullstring
        elif querystring:
            query = self.baseurl+"/xwiki/rest/"+querystring
        else:
            query = self.baseurl+"/xwiki/rest/"

        if asjson:
            resp = requests.get(query+"?media=json", auth = self.auth)
            return resp.json()
        else:
            resp = requests.get(query, auth = self.auth)
            return resp
        
    def get_apppages(self, appname = "", wiki = "xwiki", excludepage = []):
        """Gets all entries of an App directly stored in the app space"""
        applist = []
        allspaces = self.get_response(querystring = "wikis/"+wiki+"/spaces/")
        for entry in allspaces["spaces"]:
            if type(entry["home"]) is str:
                if entry["home"].find(appname+".")>0:
                    for link in entry["links"]:
                        takeit = True
                        if link["rel"] != 'http://www.xwiki.org/rel/home':
                            takeit = False
                        if link["href"].find("/Code/")>0:
                            takeit = False
                        if link["href"].find("/"+appname+"/pages/WebHome") >0:
                            takeit = False
                        for page in excludepage:
                            if link["href"].find("/"+page+"/") >0:
                                takeit = False
                        if takeit: 
                            applist.append(link["href"])
        allpages = self.get_response(querystring = "wikis/"+wiki+"/spaces/"+appname+"/pages")
        for entry in allpages["pageSummaries"]:
            for link in entry["links"]:
                if link["rel"] == 'http://www.xwiki.org/rel/page':
                    if link["href"].find("/pages/Web") < 0:
                        applist.append(link["href"])
        self.querystore.setdefault(appname+"_list", applist)
        
    def get_appentries(self, appname, wiki="xwiki", limit = -1):
        """Get all direct entries of a custonm app and according values"""
        if not appname+"_list" in self.querystore:
            self.get_apppages(appname, wiki)
        objlist = {}
        if limit>0:
            counter = 0
        for url in self.querystore[appname+"_list"]:
            objlist.setdefault(url, self.get_appobject(url, appname))
            if limit > 0:
                counter += 1
                if counter > limit:
                    break
        self.querystore.setdefault(appname+"_entries", objlist)
        
    def get_appobject(self, queryurl, appname):
        """Get object info as dictionary"""
        appinfo = talker.get_response(queryurl+"/objects/"+appname+".Code."+appname+"Class/0/properties")
        propdict = {}
        if "properties" in appinfo:
            for entry in appinfo["properties"]:
                propdict.setdefault(entry["name"], entry["value"])
        return propdict
    
    def create_page(self, parenturl, pagename, pagecontent=""):
        """Add page with a given name under a parent page"""
        if parenturl[len(parenturl)-6:len(parenturl)].find("pages") < 0:
            if parenturl[len(parenturl)-1] != "/":
                parenturl += "/"
            parenturl += "pages/"
        if parenturl.find("https")<0:
            parenturl = self.baseurl+"/xwiki/rest/"+parenturl
        pageparams = {"title": pagename, "syntax": "xwiki/2.0", "content": pagecontent}
        resp = requests.put(parenturl+pagename, data=pageparams, auth=self.auth)
        if resp.ok:
            return parenturl+pagename
        else:
            return False
        
    def add_object(self, parenturl, objectclass, objectname="", attributes = {}):
        if parenturl[len(parenturl)-1]!="/":
            parenturl += "/"
        print (parenturl + "objects")
        oldobjects = self.get_response(parenturl + "objects")
        fullurl = ""
        for entry in oldobjects['objectSummaries']:
            for link in entry["links"]:
                if link["href"].find(objectclass)>0 and not objectname:
                    fullurl = link["href"]
                elif link["href"].find(objectname)>0:
                    if objectname.find(objectclass)<0:
                        objectname = objectname + "/" + objectname
                    fullurl = link["href"]
        if not fullurl:
            postobjurl = parenturl + "objects"
            if not "." in objectclass:
                objectclass = objectclass + ".Code." + objectclass +"Class"
            resp = requests.post(postobjurl, json = {"className": objectclass}, auth=self.auth)
            if resp.ok:
                fullurl = resp.headers["Location"]
        if not fullurl:
            print ("Did not manage to find or create object "+objectname)

        objparams = {}
        for key in attributes:
            if key.find("property#")<0:
                objparams.setdefault("property#"+key, attributes[key])
            else:
                objparams.setdefault(key, attributes[key])
        print (objparams)
        resp = requests.put(fullurl.rstrip("properties"), data = objparams, auth=self.auth)
        
    def add_attachment(self, filename, parenturl, filepath = "", filepostname = ""):
        putfile = open(filepath+filename, 'rb')
        if not filepostname:
            filepostname = filename
        puturl = parenturl+ "/attachments/"+filepostname
        requests.put(puturl, data=putfile, auth=self.auth)

# %%
talker = WikiTalker("Jutta", "JRmbpq5aWGrW5j!k")

# %%
import pandas
import yaml

class Infomatcher:
    def __init__(self, sourcefile = "", matchfile = ""):
        """Initializes with sourcefile of type excel and matchfile with yaml content"""
        self.source = None
        self.match = None
        
        if matchfile != "":
            self.match = yaml.safe_load(open(matchfile, "r"))
        if sourcefile != "":
            if "formatting" in self.match:
                self.source = pandas.read_excel(sourcefile, dtype = self.match["formatting"])
            else:
                self.source = pandas.read_excel(sourcefile)

# %%
info = Infomatcher("xwiki Regionalstruktur-short.xlsx", "config_Kontakte.yml")

# %%
for row in info.source.iterrows():
    objdict = {}
    pagetitle = ""
    for key in info.match["matching"].keys():
        sentry = info.match["matching"][key]
        if key == "doctitle":
            if sentry in row[1]:
                pagetitle = row[1][sentry]
        else:
            if type(sentry) is str:
                if sentry in row[1]:
                    if not pandas.isna(row[1][sentry]):
                        value = row[1][sentry]
                        if key in mappers:
                            if value in mappers[key]:
                                value = mappers[key][value]
                        objdict.setdefault(key, value)
            elif type(sentry) is dict:
                if "display" in sentry:
                    if sentry["display"] == "usetitle":
                        result = ""
                        for val in sentry["values"]:
                            if val in row[1]:
                                if not pandas.isna(row[1][val]):
                                    result += "**"+val+"**\n"+str(row[1][val])+"\n\n"
                        objdict.setdefault(key, result)
                    elif sentry["display"] == "newlines":
                        result = ""
                        for val in sentry["values"]:
                            if val in row[1]:
                                if not pandas.isna(row[1][val]):
                                    result += str(row[1][val])+"\n"
                        objdict.setdefault(key, result)
                    else:
                        result = ""
                        for val in sentry["values"]:
                            if val in row[1]:
                                if not pandas.isna(row[1][val]):
                                    result += row[1][val]
                        objdict.setdefault(key, result)
                elif "prefix" in sentry:
                    if sentry["value"] in row[1]:
                        if not pandas.isna(row[1][sentry["value"]]):
                            objdict.setdefault(key, sentry["prefix"]+row[1][sentry["value"]])
                elif "suffix" in sentry:
                    if sentry["value"] in row[1]:
                        if not pandas.isna(row[1][sentry["value"]]):
                            objdict.setdefault(key, row[1][sentry["value"]]+sentry["suffix"])
            elif type(sentry) is list:
                result = ""
                for val in sentry:
                    if val in row[1]:
                        if not pandas.isna(row[1][val]):
                            value = row[1][val]
                            if key in mappers:
                                if value in mappers[key]:
                                    value = mappers[key][value]
                            result += value
                objdict.setdefault(key, result)
                      
    newpage = talker.create_page(info.match["parentpage"], pagetitle)
    if newpage:
        talker.add_object(newpage, info.match["objectclass"], attributes = objdict)
    print ("Created "+pagetitle)
# Out:
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Bezirk Ostwestfalen-Lippe/objects
# {'property#kontaktart': 'Bezirk', 'property#group': 'XWiki.Bezirk Ostwestfalen-Lippe', 'property#telefon': '05219679440', 'property#webseite': 'www.amnesty-owl.de', 'property#adresse': 'Jöllenbecker Str. 103\n33613\nBielefeld\n', 'property#anmerkung': '**Öffnungszeiten - Büro**\nDi 18:30-19:30 Uhr\n\n**Öffnungszeiten - Asylberatung**\nNach Vereinbarung, Telefon: 0521 17 82 03\nbzw. E-Mail: asyl@amnesty-owl.de\n\n', 'property#gruppennummer': 3480, 'property#parent': '0010900000oqA77', 'property#gruppenid': '0010900000cFDzi'}
# Created Bezirk Ostwestfalen-Lippe
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Kogruppen/objects
# {'property#kontaktart': 'Länderkogruppe', 'property#group': 'XWiki.Kogruppen', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 6999, 'property#parent': '0010900000cFDyy', 'property#gruppenid': '0010900000cFDzz'}
# Created Kogruppen
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe Hof/objects
# {'property#kontaktart': 'lokale Gruppe', 'property#group': 'XWiki.Gruppe Hof', 'property#webseite': 'http://www.amnesty-hof.de/', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 1624, 'property#parent': '0010900000cFDzO', 'property#gruppenid': '0010900000cFE0B'}
# Created Gruppe Hof
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe Ingolstadt/objects
# {'property#kontaktart': 'lokale Gruppe', 'property#group': 'XWiki.Gruppe Ingolstadt', 'property#webseite': 'http://www.ai-ingolstadt.de/', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 1273, 'property#parent': '0010900000cFECq', 'property#gruppenid': '0010900000cFE0E'}
# Created Gruppe Ingolstadt
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Jugendgr. Dt.-Frz. Gymn. Saarbrücke/objects
# {'property#kontaktart': 'Jugendgruppe', 'property#group': 'XWiki.Jugendgr. Dt.-Frz. Gymn. Saarbrücke', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 1979, 'property#parent': '0010900000cFDzQ', 'property#gruppenid': '0010900000cFE18'}
# Created Jugendgr. Dt.-Frz. Gymn. Saarbrücke
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Kogruppe Südliches Afrika/objects
# {'property#kontaktart': 'Länderkogruppe', 'property#group': 'XWiki.Kogruppe Südliches Afrika', 'property#webseite': 'https://amnesty-suedliches-afrika.de/', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 2053, 'property#parent': '0010900000cFDzz', 'property#gruppenid': '0010900000cFE1B'}
# Created Kogruppe Südliches Afrika
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Kogruppe Südwestpazifik/objects
# {'property#kontaktart': 'Länderkogruppe', 'property#group': 'XWiki.Kogruppe Südwestpazifik', 'property#webseite': 'http://www.amnesty-suedwestpazifik.de/', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 2221, 'property#parent': '0010900000cFDzz', 'property#gruppenid': '0010900000cFE1C'}
# Created Kogruppe Südwestpazifik
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Lateinamerikagruppe Aachen (1191)/objects
# {'property#kontaktart': 'lokale Gruppe', 'property#group': 'XWiki.Lateinamerikagruppe Aachen (1191)', 'property#webseite': 'http://www.amnesty-aachen.de/', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 1191, 'property#parent': '0010900000cFDz2', 'property#gruppenid': '0010900000cFE1S'}
# Created Lateinamerikagruppe Aachen (1191)
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Lateinamerikagruppe Aachen (1529)/objects
# {'property#kontaktart': 'lokale Gruppe', 'property#group': 'XWiki.Lateinamerikagruppe Aachen (1529)', 'property#webseite': 'http://www.amnesty-aachen.de/', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 1529, 'property#parent': '0010900000cFDz2', 'property#gruppenid': '0010900000cFE1T'}
# Created Lateinamerikagruppe Aachen (1529)
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Jugendgr. Gymn. Gelnhausen/objects
# {'property#kontaktart': 'Jugendgruppe', 'property#group': 'XWiki.Jugendgr. Gymn. Gelnhausen', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 1814, 'property#parent': '0010900000cFDzC', 'property#gruppenid': '0010900000cFE1d'}
# Created Jugendgr. Gymn. Gelnhausen
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Jugendgr. Karlsruhe/objects
# {'property#kontaktart': 'Jugendgruppe', 'property#group': 'XWiki.Jugendgr. Karlsruhe', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 1846, 'property#parent': '0010900000cFDzG', 'property#gruppenid': '0010900000cFE1l'}
# Created Jugendgr. Karlsruhe
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Sektionskogruppe MRB und Training/objects
# {'property#kontaktart': 'Themenkogruppe', 'property#group': 'XWiki.Sektionskogruppe MRB und Training', 'property#webseite': 'http://www.amnesty-bildung.de', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 2910, 'property#parent': '0010900000cFDzz', 'property#gruppenid': '0010900000cFE20'}
# Created Sektionskogruppe MRB und Training
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Stadtgruppe Bonn/objects
# {'property#kontaktart': 'lokale Gruppe', 'property#group': 'XWiki.Stadtgruppe Bonn', 'property#webseite': 'https://stadtgruppe.amnesty-bonn.de/', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 42, 'property#parent': '0010900000cFDz5', 'property#gruppenid': '0010900000cFE21'}
# Created Stadtgruppe Bonn
# Created Jugendgr. Stuttgart/Wirtschaftsgym. West
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Jugendgr. Uelzen, Herzog-Ernst-Gymn/objects
# {'property#kontaktart': 'Jugendgruppe', 'property#group': 'XWiki.Jugendgr. Uelzen, Herzog-Ernst-Gymn', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 1938, 'property#parent': '0010900000cFDzF', 'property#gruppenid': '0010900000cFE2E'}
# Created Jugendgr. Uelzen, Herzog-Ernst-Gymn
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Jugendgr. Waldorfschule Freiburg-Wi/objects
# {'property#kontaktart': 'Jugendgruppe', 'property#group': 'XWiki.Jugendgr. Waldorfschule Freiburg-Wi', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 1934, 'property#parent': '0010900000cFDzr', 'property#gruppenid': '0010900000cFE2G'}
# Created Jugendgr. Waldorfschule Freiburg-Wi
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Young Amnesty Hannover/objects
# {'property#kontaktart': 'Hochschulgruppe', 'property#group': 'XWiki.Young Amnesty Hannover', 'property#webseite': 'http://www.amnesty-uni-hannover.de/', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 1544, 'property#parent': '0010900000cFDzF', 'property#gruppenid': '0010900000cFE2X'}
# Created Young Amnesty Hannover
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Themenkogruppe Polizei und Menschenrechte/objects
# {'property#kontaktart': 'Themenkogruppe', 'property#group': 'XWiki.Themenkogruppe Polizei und Menschenrechte', 'property#webseite': 'https://amnesty-polizei.de/', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 2905, 'property#parent': '0010900000cFDzz', 'property#gruppenid': '0010900000cFE2W'}
# Created Themenkogruppe Polizei und Menschenrechte
# Created Gruppe Düsseldorf Süd/Hilden
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe Düsseldorf-Meerbusch/objects
# {'property#kontaktart': 'lokale Gruppe', 'property#group': 'XWiki.Gruppe Düsseldorf-Meerbusch', 'property#webseite': 'https://amnesty-duesseldorf.de/gruppe-1177/', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 1177, 'property#parent': '0010900000cFDzB', 'property#gruppenid': '0010900000cFEHH'}
# Created Gruppe Düsseldorf-Meerbusch
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Asylgruppe Eichstätt/objects
# {'property#kontaktart': 'Asylgruppe', 'property#group': 'XWiki.Asylgruppe Eichstätt', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 34, 'property#parent': '0010900000cFECq', 'property#gruppenid': '0010900000cFELw'}
# Created Asylgruppe Eichstätt
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Asylgruppe Karlsruhe/objects
# {'property#kontaktart': 'Asylgruppe', 'property#group': 'XWiki.Asylgruppe Karlsruhe', 'property#webseite': 'http://www.amnesty-asyl-karlsruhe.de', 'property#adresse': '', 'property#anmerkung': '', 'property#gruppennummer': 4, 'property#parent': '0010900000cFDzG', 'property#gruppenid': '0010900000cFELx'}
# Created Asylgruppe Karlsruhe
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Bezirk Tübingen/objects
# {'property#kontaktart': 'Bezirk', 'property#group': 'XWiki.Bezirk Tübingen', 'property#telefon': '070717956617', 'property#webseite': 'www.ai-tuebingen.de', 'property#adresse': 'Wilhelmstr. 105\n72001\nTübingen\n', 'property#anmerkung': '**Öffnungszeiten - Büro**\nDo in den ungeraden Kalenderwochen 20.00 bis 21.30 Ihr\n\n', 'property#gruppennummer': 3740, 'property#parent': '0010900000oq8rD', 'property#gruppenid': '0010900000cFDzt'}
# Created Bezirk Tübingen
# https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Bezirk Würzburg/objects
# {'property#kontaktart': 'Bezirk', 'property#group': 'XWiki.Bezirk Würzburg', 'property#telefon': '0931886927', 'property#webseite': 'www.amnesty-wuerzburg.de', 'property#adresse': 'Friedenstr. 3\n97072\nWürzburg\n', 'property#anmerkung': '', 'property#gruppennummer': 3870, 'property#parent': '0010900000oq8Ha', 'property#gruppenid': '0010900000cFDzv'}
# Created Bezirk Würzburg

# %%
talker.get_response("https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe Hof/objects/Kontakte.Code.KontakteClass/0/")
# Out:
# {'links': [{'href': 'https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe%20Hof/objects/Kontakte.Code.KontakteClass/0',
#    'rel': 'self',
#    'type': None,
#    'hrefLang': None}],
#  'id': 'devwiki:Kontakte.Gruppe Hof:599b0a70-7782-4921-bcf1-0ffa11a186ca',
#  'guid': '599b0a70-7782-4921-bcf1-0ffa11a186ca',
#  'pageId': 'devwiki:Kontakte.Gruppe Hof',
#  'pageVersion': '10.1',
#  'wiki': 'devwiki',
#  'space': 'Kontakte',
#  'pageName': 'Gruppe Hof',
#  'pageAuthor': 'xwiki:XWiki.Jutta',
#  'pageAuthorName': None,
#  'className': 'Kontakte.Code.KontakteClass',
#  'number': 0,
#  'headline': '',
#  'properties': [{'links': [{'href': 'https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe%20Hof/objects/Kontakte.Code.KontakteClass/0/properties/adresse',
#      'rel': 'self',
#      'type': None,
#      'hrefLang': None}],
#    'attributes': [{'links': [], 'name': 'name', 'value': 'adresse'},
#     {'links': [], 'name': 'prettyName', 'value': 'Adresse'},
#     {'links': [], 'name': 'unmodifiable', 'value': '0'},
#     {'links': [], 'name': 'disabled', 'value': '0'},
#     {'links': [], 'name': 'size', 'value': '40'},
#     {'links': [], 'name': 'rows', 'value': '5'},
#     {'links': [], 'name': 'contenttype', 'value': '---'},
#     {'links': [], 'name': 'customDisplay', 'value': ''},
#     {'links': [], 'name': 'editor', 'value': '---'},
#     {'links': [], 'name': 'hint', 'value': 'Postalische Adresse'},
#     {'links': [], 'name': 'number', 'value': '7'},
#     {'links': [], 'name': 'picker', 'value': '0'},
#     {'links': [], 'name': 'validationMessage', 'value': ''},
#     {'links': [], 'name': 'validationRegExp', 'value': ''}],
#    'value': '',
#    'name': 'adresse',
#    'type': 'TextArea'},
#   {'links': [{'href': 'https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe%20Hof/objects/Kontakte.Code.KontakteClass/0/properties/anmerkung',
#      'rel': 'self',
#      'type': None,
#      'hrefLang': None}],
#    'attributes': [{'links': [], 'name': 'name', 'value': 'anmerkung'},
#     {'links': [], 'name': 'prettyName', 'value': 'Anmerkungen'},
#     {'links': [], 'name': 'unmodifiable', 'value': '0'},
#     {'links': [], 'name': 'disabled', 'value': '0'},
#     {'links': [], 'name': 'size', 'value': '40'},
#     {'links': [], 'name': 'rows', 'value': '5'},
#     {'links': [], 'name': 'contenttype', 'value': '---'},
#     {'links': [], 'name': 'customDisplay', 'value': ''},
#     {'links': [], 'name': 'editor', 'value': '---'},
#     {'links': [],
#      'name': 'hint',
#      'value': 'Ergänzungen wie bevorzugte Ansprache, Öffnungszeiten, Arbeitszeiten'},
#     {'links': [], 'name': 'number', 'value': '8'},
#     {'links': [], 'name': 'picker', 'value': '0'},
#     {'links': [], 'name': 'validationMessage', 'value': ''},
#     {'links': [], 'name': 'validationRegExp', 'value': ''}],
#    'value': '',
#    'name': 'anmerkung',
#    'type': 'TextArea'},
#   {'links': [{'href': 'https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe%20Hof/objects/Kontakte.Code.KontakteClass/0/properties/email',
#      'rel': 'self',
#      'type': None,
#      'hrefLang': None}],
#    'attributes': [{'links': [], 'name': 'name', 'value': 'email'},
#     {'links': [], 'name': 'prettyName', 'value': 'Email'},
#     {'links': [], 'name': 'unmodifiable', 'value': '0'},
#     {'links': [], 'name': 'disabled', 'value': '0'},
#     {'links': [], 'name': 'size', 'value': '30'},
#     {'links': [], 'name': 'customDisplay', 'value': ''},
#     {'links': [], 'name': 'hint', 'value': 'Kontaktemail'},
#     {'links': [], 'name': 'number', 'value': '4'},
#     {'links': [], 'name': 'picker', 'value': '0'},
#     {'links': [], 'name': 'validationMessage', 'value': ''},
#     {'links': [], 'name': 'validationRegExp', 'value': ''}],
#    'value': '',
#    'name': 'email',
#    'type': 'String'},
#   {'links': [{'href': 'https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe%20Hof/objects/Kontakte.Code.KontakteClass/0/properties/group',
#      'rel': 'self',
#      'type': None,
#      'hrefLang': None}],
#    'attributes': [{'links': [], 'name': 'name', 'value': 'group'},
#     {'links': [], 'name': 'prettyName', 'value': 'Gruppe'},
#     {'links': [], 'name': 'unmodifiable', 'value': '0'},
#     {'links': [], 'name': 'disabled', 'value': '0'},
#     {'links': [], 'name': 'relationalStorage', 'value': '0'},
#     {'links': [], 'name': 'displayType', 'value': 'select'},
#     {'links': [], 'name': 'multiSelect', 'value': '0'},
#     {'links': [], 'name': 'size', 'value': '6'},
#     {'links': [], 'name': 'separator', 'value': ' '},
#     {'links': [], 'name': 'cache', 'value': '0'},
#     {'links': [], 'name': 'picker', 'value': '0'},
#     {'links': [], 'name': 'customDisplay', 'value': ''},
#     {'links': [], 'name': 'defaultValue', 'value': ''},
#     {'links': [], 'name': 'freeText', 'value': ''},
#     {'links': [],
#      'name': 'hint',
#      'value': 'XWiki Gruppe, die der zu kontaktierenden Gruppe entspricht'},
#     {'links': [], 'name': 'largeStorage', 'value': '0'},
#     {'links': [], 'name': 'number', 'value': '3'},
#     {'links': [], 'name': 'separators', 'value': ''},
#     {'links': [], 'name': 'sort', 'value': 'none'},
#     {'links': [], 'name': 'usesList', 'value': '1'},
#     {'links': [], 'name': 'validationMessage', 'value': ''},
#     {'links': [], 'name': 'validationRegExp', 'value': ''},
#     {'links': [],
#      'name': 'allowedValues',
#      'value': 'XWiki.XWikiAdminGroup,XWiki.Redaktion,XWiki.XWikiAllGroup,XWiki.XWikiNetworkTicketsGroup,XWiki.Techteam,XWiki.XWikiNetworkPaymentsGroup'}],
#    'value': 'XWiki.Gruppe Hof',
#    'name': 'group',
#    'type': 'Groups'},
#   {'links': [{'href': 'https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe%20Hof/objects/Kontakte.Code.KontakteClass/0/properties/gruppenid',
#      'rel': 'self',
#      'type': None,
#      'hrefLang': None}],
#    'attributes': [{'links': [], 'name': 'name', 'value': 'gruppenid'},
#     {'links': [], 'name': 'prettyName', 'value': 'Gruppenid'},
#     {'links': [], 'name': 'unmodifiable', 'value': '0'},
#     {'links': [], 'name': 'disabled', 'value': '0'},
#     {'links': [], 'name': 'size', 'value': '30'},
#     {'links': [], 'name': 'customDisplay', 'value': ''},
#     {'links': [], 'name': 'hint', 'value': ''},
#     {'links': [], 'name': 'number', 'value': '11'},
#     {'links': [], 'name': 'picker', 'value': '1'},
#     {'links': [], 'name': 'validationMessage', 'value': ''},
#     {'links': [], 'name': 'validationRegExp', 'value': ''}],
#    'value': '0010900000cFE0B',
#    'name': 'gruppenid',
#    'type': 'String'},
#   {'links': [{'href': 'https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe%20Hof/objects/Kontakte.Code.KontakteClass/0/properties/gruppennummer',
#      'rel': 'self',
#      'type': None,
#      'hrefLang': None}],
#    'attributes': [{'links': [], 'name': 'name', 'value': 'gruppennummer'},
#     {'links': [], 'name': 'prettyName', 'value': 'Gruppennummer'},
#     {'links': [], 'name': 'unmodifiable', 'value': '0'},
#     {'links': [], 'name': 'disabled', 'value': '0'},
#     {'links': [], 'name': 'size', 'value': '30'},
#     {'links': [], 'name': 'numberType', 'value': 'long'},
#     {'links': [], 'name': 'customDisplay', 'value': ''},
#     {'links': [], 'name': 'hint', 'value': 'Buchungsnummer der Einheit'},
#     {'links': [], 'name': 'number', 'value': '9'},
#     {'links': [], 'name': 'validationMessage', 'value': ''},
#     {'links': [], 'name': 'validationRegExp', 'value': ''}],
#    'value': '1624',
#    'name': 'gruppennummer',
#    'type': 'Number'},
#   {'links': [{'href': 'https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe%20Hof/objects/Kontakte.Code.KontakteClass/0/properties/kontaktart',
#      'rel': 'self',
#      'type': None,
#      'hrefLang': None}],
#    'attributes': [{'links': [], 'name': 'name', 'value': 'kontaktart'},
#     {'links': [], 'name': 'prettyName', 'value': 'Kontaktart'},
#     {'links': [], 'name': 'unmodifiable', 'value': '0'},
#     {'links': [], 'name': 'disabled', 'value': '0'},
#     {'links': [], 'name': 'relationalStorage', 'value': '1'},
#     {'links': [], 'name': 'displayType', 'value': 'select'},
#     {'links': [], 'name': 'multiSelect', 'value': '0'},
#     {'links': [], 'name': 'size', 'value': '1'},
#     {'links': [], 'name': 'separator', 'value': ' '},
#     {'links': [], 'name': 'cache', 'value': '0'},
#     {'links': [], 'name': 'separators', 'value': ' ,|'},
#     {'links': [], 'name': 'customDisplay', 'value': ''},
#     {'links': [], 'name': 'defaultValue', 'value': ''},
#     {'links': [], 'name': 'freeText', 'value': ''},
#     {'links': [],
#      'name': 'hint',
#      'value': 'Typ der Gruppe oder Art des Kontakts'},
#     {'links': [], 'name': 'largeStorage', 'value': '0'},
#     {'links': [], 'name': 'number', 'value': '2'},
#     {'links': [], 'name': 'picker', 'value': '0'},
#     {'links': [], 'name': 'sort', 'value': 'none'},
#     {'links': [], 'name': 'validationMessage', 'value': ''},
#     {'links': [], 'name': 'validationRegExp', 'value': ''},
#     {'links': [],
#      'name': 'values',
#      'value': 'bezirk=Bezirk|gremium=Gremium|laenderkogruppe=Länderkogruppe|lokalegruppe=lokale Gruppe|hochschulgruppe=Hochschulgruppe|jugendgruppe=Jugendgruppe|themenkogruppe=Themenkogruppe|asylgruppe=Asylgruppe|regional=Region|sds=Sekretariat'},
#     {'links': [],
#      'name': 'allowedValues',
#      'value': 'bezirk,gremium,laenderkogruppe,lokalegruppe,hochschulgruppe,jugendgruppe,themenkogruppe,asylgruppe,regional,sds'}],
#    'value': 'lokale Gruppe',
#    'name': 'kontaktart',
#    'type': 'StaticList'},
#   {'links': [{'href': 'https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe%20Hof/objects/Kontakte.Code.KontakteClass/0/properties/parent',
#      'rel': 'self',
#      'type': None,
#      'hrefLang': None}],
#    'attributes': [{'links': [], 'name': 'name', 'value': 'parent'},
#     {'links': [], 'name': 'prettyName', 'value': 'Übergeordnete Struktur'},
#     {'links': [], 'name': 'unmodifiable', 'value': '0'},
#     {'links': [], 'name': 'disabled', 'value': '0'},
#     {'links': [], 'name': 'relationalStorage', 'value': '0'},
#     {'links': [], 'name': 'displayType', 'value': 'input'},
#     {'links': [], 'name': 'multiSelect', 'value': '0'},
#     {'links': [], 'name': 'size', 'value': '20'},
#     {'links': [], 'name': 'separator', 'value': ' '},
#     {'links': [], 'name': 'cache', 'value': '0'},
#     {'links': [], 'name': 'picker', 'value': '1'},
#     {'links': [], 'name': 'customDisplay', 'value': ''},
#     {'links': [], 'name': 'defaultValue', 'value': ''},
#     {'links': [], 'name': 'freeText', 'value': ''},
#     {'links': [],
#      'name': 'hint',
#      'value': 'Übergeordnete Ebene, der die Einheit zugeordnet ist (Bezirk u.ä.)'},
#     {'links': [], 'name': 'largeStorage', 'value': '0'},
#     {'links': [], 'name': 'number', 'value': '10'},
#     {'links': [], 'name': 'separators', 'value': ''},
#     {'links': [], 'name': 'sort', 'value': ''},
#     {'links': [], 'name': 'usesList', 'value': '0'},
#     {'links': [], 'name': 'validationMessage', 'value': ''},
#     {'links': [], 'name': 'validationRegExp', 'value': ''},
#     {'links': [],
#      'name': 'allowedValues',
#      'value': 'XWiki.XWikiAdminGroup,XWiki.Redaktion,XWiki.XWikiAllGroup,XWiki.XWikiNetworkTicketsGroup,XWiki.Techteam,XWiki.XWikiNetworkPaymentsGroup'}],
#    'value': '0010900000cFDzO',
#    'name': 'parent',
#    'type': 'Groups'},
#   {'links': [{'href': 'https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe%20Hof/objects/Kontakte.Code.KontakteClass/0/properties/telefon',
#      'rel': 'self',
#      'type': None,
#      'hrefLang': None}],
#    'attributes': [{'links': [], 'name': 'name', 'value': 'telefon'},
#     {'links': [], 'name': 'prettyName', 'value': 'Telefon'},
#     {'links': [], 'name': 'unmodifiable', 'value': '0'},
#     {'links': [], 'name': 'disabled', 'value': '0'},
#     {'links': [], 'name': 'size', 'value': '30'},
#     {'links': [], 'name': 'customDisplay', 'value': ''},
#     {'links': [], 'name': 'hint', 'value': 'Telefonnummer für Anfrage'},
#     {'links': [], 'name': 'number', 'value': '5'},
#     {'links': [], 'name': 'picker', 'value': '0'},
#     {'links': [], 'name': 'validationMessage', 'value': ''},
#     {'links': [], 'name': 'validationRegExp', 'value': ''}],
#    'value': '',
#    'name': 'telefon',
#    'type': 'String'},
#   {'links': [{'href': 'https://amnesty.cloud.xwiki.com/xwiki/rest/wikis/devwiki/spaces/Kontakte/pages/Gruppe%20Hof/objects/Kontakte.Code.KontakteClass/0/properties/webseite',
#      'rel': 'self',
#      'type': None,
#      'hrefLang': None}],
#    'attributes': [{'links': [], 'name': 'name', 'value': 'webseite'},
#     {'links': [], 'name': 'prettyName', 'value': 'Webseite'},
#     {'links': [], 'name': 'unmodifiable', 'value': '0'},
#     {'links': [], 'name': 'disabled', 'value': '0'},
#     {'links': [], 'name': 'size', 'value': '30'},
#     {'links': [], 'name': 'customDisplay', 'value': ''},
#     {'links': [], 'name': 'hint', 'value': ''},
#     {'links': [], 'name': 'number', 'value': '6'},
#     {'links': [], 'name': 'picker', 'value': '1'},
#     {'links': [], 'name': 'validationMessage', 'value': ''},
#     {'links': [], 'name': 'validationRegExp', 'value': ''}],
#    'value': 'http://www.amnesty-hof.de/',
#    'name': 'webseite',
#    'type': 'String'}]}
